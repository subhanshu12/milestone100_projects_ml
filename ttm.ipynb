001,25.940001,25.92,26.389999,26.26,26.389999,27.299999,26.809999,26.549999,25.549999,25.190001,24.91,24.959999,24.719999,24.73,25.16,25.16,24.459999],"high":[32.299999,30.77,29.57,30.43,31.52,31.42,31.790001,32.080002,31.66,31.66,32.369999,33.599998,33.0,32.720001,33.060001,32.919998,33.880001,34.18,34.700001,34.650002,34.52,34.330002,35.080002,34.900002,33.470001,31.530001,32.5,32.389999,32.990002,32.830002,33.970001,33.57,33.830002,33.700001,33.25,33.060001,33.029999,34.5,33.880001,33.18,31.25,33.349998,33.290001,33.220001,33.009998,32.130001,32.200001,29.379999,31.0,30.57,30.120001,29.98,29.27,26.65,25.84,25.68,26.91,26.860001,27.639999,26.700001,27.77,28.459999,28.33,28.6,27.889999,29.16,28.57,28.65,28.41,28.700001,29.59,28.780001,28.34,29.23,29.74,30.33,29.82,29.51,30.459999,29.85,28.99,28.139999,27.99,28.73,28.25,29.17,29.59,28.610001,27.98,28.24,28.309999,28.57,28.83,28.299999,28.74,28.120001,27.700001,26.84,25.950001,25.58,25.5,24.389999,26.59,26.35,27.68,27.190001,26.440001,27.190001,27.65,27.440001,27.459999,28.27,28.219999,28.780001,29.15,28.809999,28.049999,28.32,28.190001,28.26,27.610001,27.17,25.93,26.27,26.92,25.33,25.360001,26.25,25.879999,26.1,26.719999,26.709999,26.76,26.540001,25.98,26.33,26.15,26.57,27.879999,28.09,27.540001,27.42,26.879999,26.959999,27.84,28.4,28.67,28.51,28.73,28.59,28.139999,27.68,27.6,28.219999,28.66,30.700001,30.530001,30.1,29.74,29.27,29.73,29.59,30.99,30.440001,30.459999,30.51,31.25,30.620001,30.74,29.73,28.389999,29.110001,29.290001,29.25,29.57,28.68,29.67,29.16,29.27,29.35,28.530001,28.389 ...

# %% [markdown]
# # Now let’s have a look at the correlation between the features of this dataset:

# %%
print(data.corr())
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.996003  0.995004  0.989621   0.989621  0.024086
# High       0.996003  1.000000  0.994692  0.995089   0.995089  0.040071
# Low        0.995004  0.994692  1.000000  0.995196   0.995196 -0.008501
# Close      0.989621  0.995089  0.995196  1.000000   1.000000  0.008017
# Adj Close  0.989621  0.995089  0.995196  1.000000   1.000000  0.008017
# Volume     0.024086  0.040071 -0.008501  0.008017   0.008017  1.000000

# %% [markdown]
# # Now let’s move to the task of predicting the stock prices of Tata Motors. Here I will be using the autots library in Python to prepare the stock prices of Tata Motors for the next 5 days. If you have never used this Python library before, then you can easily install it by using the pip command:

# %%
# !pip install autots
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting autots
#   Downloading AutoTS-0.5.2-py3-none-any.whl (674 kB)
#      |████████████████████████████████| 674 kB 4.7 MB/s
# Requirement already satisfied: statsmodels>=0.10.* in /usr/local/lib/python3.8/dist-packages (from autots) (0.12.2)
# Requirement already satisfied: scikit-learn>=0.20.* in /usr/local/lib/python3.8/dist-packages (from autots) (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.8/dist-packages (from autots) (1.21.6)
# Requirement already satisfied: pandas>=0.25.* in /usr/local/lib/python3.8/dist-packages (from autots) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25.*->autots) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25.*->autots) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.*->autots) (1.15.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.*->autots) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.*->autots) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.*->autots) (3.1.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.10.*->autots) (0.5.3)
# Installing collected packages: autots
# Successfully installed autots-0.5.2

# %%
from autots import AutoTS
model = AutoTS(forecast_length=5, frequency='infer', ensemble='simple')
model = model.fit(data, date_col='Date', value_col='Close', id_col=None)
prediction = model.predict()
forecast = prediction.forecast
print(forecast)

# %% [markdown]
# # ***BY - SUBHANSHU TRIPATHI***
